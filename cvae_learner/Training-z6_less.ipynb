# %%
import openravepy
import rospy
import os
import herbpy
from prpy import serialization

env, robot = herbpy.initialize(sim=True, attach_viewer='interactivemarker')

from catkin.find_in_workspaces import find_in_workspaces

package_name = 'pr_ordata'
directory = 'data'
objects_path = find_in_workspaces(
    search_dirs=['share'],
    project=package_name,
    path=directory,
    first_match_only=True)
if len(objects_path) == 0:
    print('Can\'t find directory %s/%s' % (package_name, directory))
    sys.exit()
else:
    print objects_path # for me this is '/home/USERNAME/catkin_workspaces/herb_ws/src/pr-ordata/data/objects'
    objects_path = objects_path[0]
    
robot.right_arm.SetActive()
# Load table from pr_ordata
table_file = os.path.join(objects_path,'objects/table.kinbody.xml')
tall_white_box_file = os.path.join(objects_path,'objects/tall_white_box.kinbody.xml')
table = env.ReadKinBodyXMLFile(table_file)
env.AddKinBody(table)
tall_white_box = env.ReadKinBodyXMLFile(tall_white_box_file)
env.AddKinBody(tall_white_box)
# Out:
# [INFO] [prpy.controllers.trigger_controller:trigger_controller.py:21]:__init__: Trigger Controller initialized
# [INFO] [prpy.controllers.trigger_controller:trigger_controller.py:21]:__init__: Trigger Controller initialized
# ['/home/vernwalrahul/projects/catkin_ws/src/pr_ordata/data']

# %%
# Workspace problem with several narrow gaps

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.gridspec as gridspec
from mpl_toolkits.mplot3d import Axes3D
import os
import csv
from random import randint, random
import time

# (restrict tensorflow memory growth)
os.environ["CUDA_VISIBLE_DEVICES"]="1"
config = tf.ConfigProto()
config.gpu_options.allow_growth=True
# Out:
# /usr/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/usr/local/lib/python2.7/dist-packages/virtualenvwrapper': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /usr/lib/python2.7/pkgutil.py:186: ImportWarning: Not importing directory '/usr/local/lib/python2.7/dist-packages/google': missing __init__.py
#   file, filename, etc = imp.find_module(subname, path)
# /usr/lib/python2.7/dist-packages/scipy/ndimage/measurements.py:36: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility
#   from . import _ni_label

# %%
# neural network parameters
mb_size = 256
h_Q_dim = 512
h_P_dim = 512

c = 0
# learning rate
lr = 1e-4

# problem dimensions
dim = 8
dataElements = dim*3 + 32 # sample (7D), init (7D), goal (7D), cond (16+16 points (table + box)) //total = 37

z_dim = 6 # latent
X_dim = dim # samples
y_dim = dim # reconstruction of the original point
c_dim = dataElements - dim # dimension of conditioning variable

# %%
#Pre-Processing

import os
import argparse
import networkx as nx
import math        
import numpy as np

def state_to_numpy(state):
    strlist = state.split()
    val_list = [float(s) for s in strlist]
    return np.array(val_list)

def list_all_dir(data_dir):
    task_dirs = os.listdir(data_dir)

    list_dir = []
    for task_dir in task_dirs:
        env_dirs = os.listdir(data_dir+"/"+task_dir)
        for env_dir in env_dirs:
            list_dir.append(data_dir +"/"+ task_dir +"/"+ env_dir)
    return list_dir  

def process_it(G, directory):
    start = np.loadtxt(directory+"/start_node.txt")
    goal = np.loadtxt(directory+"/goal_node.txt")
    cond = np.loadtxt(directory+"/conditions.txt")
    # occ_grid = occ_grid.split(",")
    path_nodes = []
    i = 0
    all_data = []
    with open(directory + "/path_nodes.txt", 'r') as file:
        lines  = file.readlines()
        for line in lines:
            line = line.strip('\n')
#             print(line)
#             print("\n\n")
            
            s = state_to_numpy(G.node[str(int(start[i]))]['state'])
            g = state_to_numpy(G.node[str(int(goal[i]))]['state'])
#             og = occ_grid[i]
            path_nodes = str(line).split(",")
            # print(path_nodes)
            for path_node in path_nodes:
                if(path_node=='-1'):
                    continue
                node_conf = state_to_numpy(G.node[path_node]['state'])
                curr_node = np.array([])
                # print("Data = ",node_conf, s, g, occ_grid)
#                     print("\n")
#                     print("node_conf = ", node_conf, " s = ", s, " g = ",g)

                curr_node = np.concatenate((node_conf, s, g, cond))
#                     print("shape of curr_node = ", curr_node.shape)
                all_data.append(curr_node)
            i+=1
    return all_data
# Out:
# /usr/lib/python2.7/dist-packages/scipy/spatial/__init__.py:90: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility
#   from .ckdtree import *
# /usr/lib/python2.7/dist-packages/scipy/spatial/__init__.py:91: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility
#   from .qhull import *
# /usr/lib/python2.7/dist-packages/scipy/special/__init__.py:531: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility
#   from ._ufuncs import *

# %%
G = nx.read_graphml("graphs/modified_graph_8D30000_3lacs.graphml")
data_dir = "data_21June"

directories = list_all_dir(data_dir)
final_data = []
flag = 0

for directory in directories:
    data = np.array(process_it(G, directory))
    if(flag==0):
        flag=1
        final_data = data
    else:
        final_data = np.concatenate((final_data, data))


data = final_data
np.random.shuffle(data)
print("shape of array: ",data.shape)

numEntries = data.shape[0]

# # read in data from csv
# filename = 'samplingdata.txt'
# f = open(filename, 'rb')
# reader = csv.reader(f, delimiter=',')
# count = 0
# data_list = []
# for row in reader:
#     data_list.append(map(float,row[0:dataElements]))

# data = np.array(data_list,dtype='d')

# ######################### Comment it #############
# # data[:,3:6] = 0
# ##################################################
# print("shape of array: ",data.shape)

# numEntries = data.shape[0]
# Out:
# ('shape of array: ', (7067, 56))

# %%
# split the inputs and conditions into test train (to be processed in the next step into an occupancy grid representation)
ratioTestTrain = 0.8;
numTrain = int(numEntries*ratioTestTrain)

X_train = data[0:numTrain,0:dim] # state: x, y, z, xdot, ydot, zdot
c_train = data[0:numTrain,dim:dataElements] # conditions: gaps, init (6), goal (6)

X_test = data[numTrain:numEntries,0:dim]
c_test = data[numTrain:numEntries,dim:dataElements]

#########################################################
c_train1 = []
c_test1 = []
c_train1 = c_train
c_test1 = c_test
#########################################################
numTest = X_test.shape[0]

# print("shape of final obstacle = ",obs.shape)
print("shape of c_train1 = ", c_train1.shape)
print("shape of c_test1 = ",c_test1.shape)
# Out:
# ('shape of c_train1 = ', (5653, 48))
# ('shape of c_test1 = ', (1414, 48))

# %%
# define networks
X = tf.placeholder(tf.float32, shape=[None, X_dim])
c = tf.placeholder(tf.float32, shape=[None, c_dim])

# Q
inputs_Q = tf.concat(axis=1, values=[X,c])

dense_Q1 = tf.layers.dense(inputs=inputs_Q, units=h_Q_dim, activation=tf.nn.relu)
dropout_Q1 = tf.layers.dropout(inputs=dense_Q1, rate=0.5)
dense_Q2 = tf.layers.dense(inputs=dropout_Q1, units=h_Q_dim, activation=tf.nn.relu)

z_mu = tf.layers.dense(inputs=dense_Q2, units=z_dim) # output here is z_mu
z_logvar = tf.layers.dense(inputs=dense_Q2, units=z_dim) # output here is z_logvar

# P
eps = tf.random_normal(shape=tf.shape(z_mu))
z = z_mu + tf.exp(z_logvar / 2) * eps
# z_sigma = tf.exp(z_logvar /2)
inputs_P = tf.concat(axis=1, values=[z,c])

dense_P1 = tf.layers.dense(inputs=inputs_P, units=h_P_dim, activation=tf.nn.relu)
dropout_P1 = tf.layers.dropout(inputs=dense_P1, rate=0.5)
dense_P2 = tf.layers.dense(inputs=dropout_P1, units=h_P_dim, activation=tf.nn.relu)

y = tf.layers.dense(inputs=dense_P2, units=X_dim) # fix to also output y

# training
########### comment in the one with 0 weight and uncomment the other ###########
w = [[1, 1, 1, 1, 1, 1, 1, 1]];
# w = [[1, 1, 1, 0, 0, 0]];
recon_loss = tf.losses.mean_squared_error(labels=X, predictions=y, weights=w)

# TODO: fix loss function for angles going around
kl_loss = 10**-4 * 2 * tf.reduce_sum(tf.exp(z_logvar) + z_mu**2 - 1. - z_logvar, 1)

cvae_loss = tf.reduce_mean(kl_loss + recon_loss)

train_step = tf.train.AdamOptimizer(lr).minimize(cvae_loss)

sess = tf.Session(config=config)
sess.run(tf.global_variables_initializer())
it = 0;

# %%
saver = tf.train.Saver()
path_ = os.getcwd() + "/checkpoints_z6_21Junedata_less/model.ckpt"
print("path = ",path_)
print("numTrain = ",numTrain)
try:
    saver.restore(sess, path_)
    print("Model Restored!!")
except Exception as e:
    print("Could not restore checkpoint!")
    print(e)
x1 = []
y1 = []    
mu = []
sigma = []
n_ = []
for it in range(it,it+500001):
    # randomly generate batches
    batch_elements = [randint(0,numTrain-1) for n in range(0,mb_size)]
    X_mb = X_train[batch_elements,:]
    c_mb = c_train1[batch_elements,:]
    
    _, loss, r = sess.run([train_step, cvae_loss, recon_loss], feed_dict={X: X_mb, c: c_mb})

#     _, loss, m, s = sess.run([train_step, cvae_loss, z_mu, z_sigma], feed_dict={X: X_mb, c: c_mb})

    if it % 1000 == 0:
        print('Iter: {}'.format(it))
        print('Loss: {:.7}'. format(loss))
        print('Recon_Loss: {:.7}'.format(r))
        print("kl_loss = ", loss-r)
#         mu.append(m)
#         sigma.append(s)
        n_.append(it)
        saver.save(sess, path_)
        print("saved session to ", path_)
# Out:
# ('path = ', '/home/vernwalrahul/projects/LearningRoadmaps/cvae_learner/checkpoints_z6_21Junedata_less/model.ckpt')
# ('numTrain = ', 5653)
# [INFO] [tensorflow:tf_logging.py:116]:info: Restoring parameters from /home/vernwalrahul/projects/LearningRoadmaps/cvae_learner/checkpoints_z6_21Junedata_less/model.ckpt
# Model Restored!!
# Iter: 0
# Loss: 0.01325719
# Recon_Loss: 0.005364824
# ('kl_loss = ', 0.0078923665)
# ('saved session to ', '/home/vernwalrahul/projects/LearningRoadmaps/cvae_learner/checkpoints_z6_21Junedata_less/model.ckpt')
# Iter: 1000
# Loss: 0.01118424
# Recon_Loss: 0.003219285
# ('kl_loss = ', 0.007964954)
# ('saved session to ', '/home/vernwalrahul/projects/LearningRoadmaps/cvae_learner/checkpoints_z6_21Junedata_less/model.ckpt')
# Iter: 2000
# Loss: 0.01038458
# Recon_Loss: 0.002553222
# ('kl_loss = ', 0.007831357)
# ('saved session to ', '/home/vernwalrahul/projects/LearningRoadmaps/cvae_learner/checkpoints_z6_21Junedata_less/model.ckpt')
# Iter: 3000
# Loss: 0.01014337
# Recon_Loss: 0.002187503
# ('kl_loss = ', 0.007955862)
# ('saved session to ', '/home/vernwalrahul/projects/LearningRoadmaps/cvae_learner/checkpoints_z6_21Junedata_less/model.ckpt')
# Iter: 4000
# Loss: 0.009885983
# Recon_Loss: 0.002071048
# ('kl_loss = ', 0.0078149345)
# ('saved session to ', '/home/vernwalrahul/projects/LearningRoadmaps/cvae_learner/checkpoints_z6_21Junedata_less/model.ckpt')
# Iter: 5000
# Loss: 0.009729382
# Recon_Loss: 0.001886735
# ('kl_loss = ', 0.007842646)
# ('saved session to ', '/home/vernwalrahul/projects/LearningRoadmaps/cvae_learner/checkpoints_z6_21Junedata_less/model.ckpt')
# Iter: 6000
# Loss: 0.009711334
# Recon_Loss: 0.001884015
# ('kl_loss = ', 0.007827319)
# ('saved session to ', '/home/vernwalrahul/projects/LearningRoadmaps/cvae_learner/checkpoints_z6_21Junedata_less/model.ckpt')
# Iter: 7000
# Loss: 0.009602917
# Recon_Loss: 0.00184181
# ('kl_loss = ', 0.0077611073)
# ('saved session to ', '/home/vernwalrahul/projects/LearningRoadmaps/cvae_learner/checkpoints_z6_21Junedata_less/model.ckpt')
# Iter: 8000
# Loss: 0.009635408
# Recon_Loss: 0.001805337
# ('kl_loss = ', 0.007830071)
# ('saved session to ', '/home/vernwalrahul/projects/LearningRoadmaps/cvae_learner/checkpoints_z6_21Junedata_less/model.ckpt')
# Iter: 9000
# Loss: 0.009378256
# Recon_Loss: 0.001727621
# ('kl_loss = ', 0.0076506357)
# ('saved session to ', '/home/vernwalrahul/projects/LearningRoadmaps/cvae_learner/checkpoints_z6_21Junedata_less/model.ckpt')
# Iter: 10000
# Loss: 0.009327447
# Recon_Loss: 0.001589055
# ('kl_loss = ', 0.007738392)
# ('saved session to ', '/home/vernwalrahul/projects/LearningRoadmaps/cvae_learner/checkpoints_z6_21Junedata_less/model.ckpt')
# Iter: 11000
# Loss: 0.009278696
# Recon_Loss: 0.001484171
# ('kl_loss = ', 0.007794525)
# ('saved session to ', '/home/vernwalrahul/projects/LearningRoadmaps/cvae_learner/checkpoints_z6_21Junedata_less/model.ckpt')
# Iter: 12000
# Loss: 0.009379923
# Recon_Loss: 0.001609965
# ('kl_loss = ', 0.007769958)
# ('saved session to ', '/home/vernwalrahul/projects/LearningRoadmaps/cvae_learner/checkpoints_z6_21Junedata_less/model.ckpt')
# Iter: 13000
# Loss: 0.009439016
# Recon_Loss: 0.001654568
# ('kl_loss = ', 0.0077844476)
# ('saved session to ', '/home/vernwalrahul/projects/LearningRoadmaps/cvae_learner/checkpoints_z6_21Junedata_less/model.ckpt')
# Iter: 14000
# Loss: 0.009330738
# Recon_Loss: 0.001590061
# ('kl_loss = ', 0.0077406773)
# ('saved session to ', '/home/vernwalrahul/projects/LearningRoadmaps/cvae_learner/checkpoints_z6_21Junedata_less/model.ckpt')
# Iter: 15000
# Loss: 0.009415344
# Recon_Loss: 0.001563338
# ('kl_loss = ', 0.007852007)
# ('saved session to ', '/home/vernwalrahul/projects/LearningRoadmaps/cvae_learner/checkpoints_z6_21Junedata_less/model.ckpt')
# Iter: 16000
# Loss: 0.009494068
# Recon_Loss: 0.001752106
# ('kl_loss = ', 0.0077419616)
# ('saved session to ', '/home/vernwalrahul/projects/LearningRoadmaps/cvae_learner/checkpoints_z6_21Junedata_less/model.ckpt')
# Iter: 17000
# Loss: 0.009290387
# Recon_Loss: 0.001510475
# ('kl_loss = ', 0.0077799116)
# ('saved session to ', '/home/vernwalrahul/projects/LearningRoadmaps/cvae_learner/checkpoints_z6_21Junedata_less/model.ckpt')
# Iter: 18000
# Loss: 0.009278353
# Recon_Loss: 0.001515855
# ('kl_loss = ', 0.007762498)
# ('saved session to ', '/home/vernwalrahul/projects/LearningRoadmaps/cvae_learner/checkpoints_z6_21Junedata_less/model.ckpt')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-367ee496f078> in <module>()
#      20     c_mb = c_train1[batch_elements,:]
#      21
# ---> 22     _, loss, r = sess.run([train_step, cvae_loss, recon_loss], feed_dict={X: X_mb, c: c_mb})
#      23
#      24 #     _, loss, m, s = sess.run([train_step, cvae_loss, z_mu, z_sigma], feed_dict={X: X_mb, c: c_mb})
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     898     try:
#     899       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 900                          run_metadata_ptr)
#     901       if run_metadata:
#     902         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1133     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1134       results = self._do_run(handle, final_targets, final_fetches,
# -> 1135                              feed_dict_tensor, options, run_metadata)
#    1136     else:
#    1137       results = []
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1314     if handle is None:
#    1315       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1316                            run_metadata)
#    1317     else:
#    1318       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1320   def _do_call(self, fn, *args):
#    1321     try:
# -> 1322       return fn(*args)
#    1323     except errors.OpError as e:
#    1324       message = compat.as_text(e.message)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1305       self._extend_graph()
#    1306       return self._call_tf_sessionrun(
# -> 1307           options, feed_dict, fetch_list, target_list, run_metadata)
#    1308
#    1309     def _prun_fn(handle, feed_dict, fetch_list):
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1407       return tf_session.TF_SessionRun_wrapper(
#    1408           self._session, options, feed_dict, fetch_list, target_list,
# -> 1409           run_metadata)
#    1410     else:
#    1411       with errors.raise_exception_on_not_ok_status() as status:
#
# KeyboardInterrupt:

# %%
print(c,z)
def create_samples(G, directory):
    start = np.loadtxt(directory+"/start_node.txt")
    goal = np.loadtxt(directory+"/goal_node.txt")
    cond = np.loadtxt(directory+"/conditions.txt")
#     cond = np.array([cond[23]])
    def state_to_numpy(state):
        strlist = state.split()
        val_list = [float(s) for s in strlist]
        return np.array(val_list)
    
    # cond = cond.split(",")
    path_nodes = []
    i = 0
    c_samples = []
    with open(directory + "/path_nodes.txt", 'r') as file:
        lines  = file.readlines()
        for line in lines:
            line = line.strip('\n')
#             print(line)
#             print("\n\n")
            if(not line == '-1'):
                s = state_to_numpy(G.node[str(int(start[i]))]['state'])
                g = state_to_numpy(G.node[str(int(goal[i]))]['state'])
                path_nodes = str(line).split(",")
                # print(path_nodes)
                for path_node in path_nodes:
                    node_conf = state_to_numpy(G.node[path_node]['state'])
                    curr_node = np.array([])
                    # print("Data = ",node_conf, s, g, cond)
#                     print("\n")
                    curr_node = np.concatenate((s, g, cond))
                    c_samples.append(curr_node)
    return np.array(c_samples)
print("c, z = ",c, z)
# Out:
# (<tf.Tensor 'Placeholder_1:0' shape=(?, 48) dtype=float32>, <tf.Tensor 'add:0' shape=(?, 6) dtype=float32>)
# ('c, z = ', <tf.Tensor 'Placeholder_1:0' shape=(?, 48) dtype=float32>, <tf.Tensor 'add:0' shape=(?, 6) dtype=float32>)

# %%
num_v = [200, 300, 400, 500]
c_final = []
print("c, z = ", c, z)
import networkx as nx
from random import choice
G = nx.read_graphml("graphs/modified_graph_30000.graphml")

dire = ["test_data_11June/T1/4", "test_data_11June/T1/7", "test_data_11June/T2/0", "test_data_11June/T2/4", "test_data_11June/T2/7", "test_data_11June/T2/14"]
# dire = ["temp_data/T2/5", "temp_data/T1/5"]
for num_viz in num_v:
    for directory in dire:
        c_final = []
        c_samples = np.float32(create_samples(G, directory))
    
        for i in range(num_viz):
            c_final.append(choice(c_samples))
        z_final = np.random.randn(num_viz,z_dim)
    
        c_final = np.array(c_final)
        print("c_final_dim = ",c_final.shape)
        print("z_dim = ",z_final.shape)
        # directly sample from the latent space (preferred, what we will use in the end)
        y_viz, z_viz = sess.run([y, z], feed_dict={z: z_final, c: c_final})
    
        print(y_viz)
        np.savetxt(directory+"/output_samples_z"+str(z_dim)+"_n"+str(num_viz)+".txt", y_viz, delimiter=" ", fmt="%s")
# Out:
# /usr/lib/python2.7/dist-packages/scipy/spatial/__init__.py:90: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility
#   from .ckdtree import *
# /usr/lib/python2.7/dist-packages/scipy/spatial/__init__.py:91: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility
#   from .qhull import *
# ('c, z = ', <tf.Tensor 'Placeholder_1:0' shape=(?, 46) dtype=float32>, <tf.Tensor 'add:0' shape=(?, 6) dtype=float32>)
# ('c_final_dim = ', (200, 46))
# ('z_dim = ', (200, 6))
# [[ 4.3858886   0.34247303  2.2838013  ... -3.3539922   0.3500365
#    0.8840044 ]
#  [ 1.9134026  -2.3107345  -2.7373729  ... -1.7544674   1.167941
#   -3.1097145 ]
#  [-0.06227186 -0.8497866   0.09701348 ... -2.5975764   1.6144634
#   -0.47727787]
#  ...
#  [ 2.243677   -0.50401115 -0.33570597 ... -2.1474974   0.53093666
#   -2.410282  ]
#  [ 3.5663154  -0.5198539  -0.4479488  ...  0.1741155   0.966961
#    0.97453594]
#  [ 2.0107136  -1.4369714  -0.06774785 ... -3.7987247   1.893209
#   -0.35732245]]
# ('c_final_dim = ', (200, 46))
# ('z_dim = ', (200, 6))
# [[
]
# ('c_final_dim = ', (500, 46))
# ('z_dim = ', (500, 6))
# [[ 4.489618   -0.6987307   1.5779027  ... -0.18294536 -1.003342
#    1.1636051 ]
#  [ 2.8306353  -1.8435847   0.6429272  ...  0.37452644 -1.4888786
#    0.9567214 ]
#  [ 5.7158656  -0.46509174 -1.5531853  ... -2.1568604   2.0178218
#   -0.30624926]
#  ...
#  [ 2.7684507   0.29745117  0.61896116 ... -3.8089352  -0.7293664
#   -0.5620819 ]
#  [ 1.3411735  -1.8762456  -0.28380296 ... -0.8841583  -0.29376286
#    0.35810542]
#  [ 2.102387    0.84141713  1.7531339  ... -1.5797361   0.9651265
#    0.7025903 ]]
# ('c_final_dim = ', (500, 46))
# ('z_dim = ', (500, 6))
# [[ 2.6299922   0.30618364 -1.2868701  ... -3.7662067  -1.2967533
#    0.19360287]
#  [ 5.124723    0.52346325  1.4487134  ... -1.2733943  -1.6579477
#    1.570057  ]
#  [ 3.740407   -0.8732453  -1.2402225  ... -2.0670774  -0.42942816
#   -1.1893582 ]
#  ...
#  [ 4.725572    1.5638142   0.6850136  ... -3.1874795   0.08084091
#   -1.1879746 ]
#  [ 4.2864056   1.2458735   0.8838333  ... -2.0663438   0.5900142
#    0.8073895 ]
#  [ 2.9696116   0.95434684 -1.8258748  ... -0.5736637  -2.4250507
#   -0.02971954]]
# ('c_final_dim = ', (500, 46))
# ('z_dim = ', (500, 6))
# [[ 1.2346603  -0.12269203 -1.0929921  ... -0.83799684  0.66263086
#    0.84351677]
#  [ 2.420035    1.3416599  -0.827556   ... -2.2959003   0.86204505
#   -0.6135636 ]
#  [ 1.3195032  -0.31766453 -0.04608796 ... -0.39479518  0.708029
#   -2.9856398 ]
#  ...
#  [ 3.01141    -0.53117496  2.0870433  ... -0.8417678   0.31389344
#   -1.7981203 ]
#  [ 4.054227    1.0369874  -0.21406491 ... -3.1733727   0.5890536
#    0.4634843 ]
#  [ 3.0850487   1.0127693  -0.73193693 ... -1.6128767   0.9424948
#   -0.87448573]]
# ('c_final_dim = ', (500, 46))
# ('z_dim = ', (500, 6))
# [[ 2.8798206  -1.1693445   1.9572805  ... -2.266395   -0.8443775
#   -1.9756371 ]
#  [ 4.519563    0.07278757  1.018514   ... -2.8131287   0.444145
#   -3.086923  ]
#  [ 4.8142476  -0.57420814 -0.22662865 ... -1.9686362  -1.5122161
#    0.65655905]
#  ...
#  [ 1.8342608  -0.04833353  1.3428637  ... -1.7254417  -0.14480327
#    0.36891845]
#  [ 4.09605    -0.9103085  -0.93929225 ... -1.9299976  -0.64314216
#    0.3776801 ]
#  [ 4.0408483   1.0693562   0.8286419  ... -0.5332576  -1.2403222
#    1.3461229 ]]
# /usr/lib/python2.7/dist-packages/scipy/special/__init__.py:531: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility
#   from ._ufuncs import *

# %%
from visualization_msgs.msg import Marker
from visualization_msgs.msg import MarkerArray
import herbpy
import os

def load_herb_and_env(cond): #46 parameters (s, g, table_pos, box_pos)
    s_conf = cond[:7]
    g_conf = cond[8:15]
    table_pose = cond[16:32].reshape(4,4)
    box_pose   = cond[32:48].reshape(4,4)
    
    table.SetTransform(table_pose)
    tall_white_box.SetTransform(box_pose)
    
    return env, robot

def get_eepositions_from_samples(env, robot, samples_conf):
    eepositions = []
    for i in range(len(samples_conf)):
            conf = samples_conf[i,:]
#             print(conf)
            robot.SetActiveDOFValues(conf[:-1])
            ee_trans = robot.right_arm.GetEndEffectorTransform()
            trans = ee_trans[0:3,3]
            eepos = trans.tolist()
            eepositions.append(eepos)
            ee_trans = robot.right_arm.GetEndEffectorTransform()
            # box_pose = get_box_pose("box_pose.txt")
            step_size = 0.1
            stick_len = 0.4
            prop = conf[-1]
            
            push_dir = ee_trans[:3,2]
            parr_dir = ee_trans[:3,1]
            box_pose1 = ee_trans
            box_pose1[:3,3] += push_dir*step_size
            box_pose1[:3,3] += parr_dir*stick_len*prop
            # box_pose[0,3], box_pose[1,3], box_pose[2,3] = eepos 
            
            stick.SetTransform(box_pose1)
#             print("prop = ", prop)
#             print("setting stick transform at ", box_pose1[:3,3])
    return eepositions

def load_marker(eepositions, markerArray, c = [0.0, 0.0, 1.0]):
    i = 0
    for e in eepositions:
            marker = Marker()
            marker.header.frame_id = "/map"
            marker.type = marker.SPHERE
            marker.action = marker.ADD
            marker.scale.x = 0.05
            marker.scale.y = 0.05
            marker.scale.z = 0.05
            marker.color.a = 1.0
            marker.color.r = c[0]
            marker.color.g = c[1]
            marker.color.b = c[2]
            marker.pose.orientation.w = 1.0
            marker.pose.position.x = e[0]
            marker.pose.position.y = e[1] 
            marker.pose.position.z = e[2]
            markerArray.markers.append(marker)
            i += 1

    return eepositions, markerArray

def publish_samples(eepositions, ee_sg, publisher):
#     ee_sg = get_eepositions_from_samples(env, robot, np.array([s_conf, g_conf]))
    markerArray = MarkerArray()
    eepositions, markerArray = load_marker(eepositions, markerArray)
    
    #adding start node
    marker = Marker()
    marker.header.frame_id = "/map"
    marker.type = marker.SPHERE
    marker.action = marker.ADD
    marker.scale.x = 0.08
    marker.scale.y = 0.08
    marker.scale.z = 0.08
    marker.color.a = 1.0
    marker.color.r = 1
    marker.color.g = 0
    marker.color.b = 0
    marker.pose.orientation.w = 1.0
    marker.pose.position.x = ee_sg[0][0]
    marker.pose.position.y = ee_sg[0][1] 
    marker.pose.position.z = ee_sg[0][2]
    markerArray.markers.append(marker)
    
    #adding goal node
    marker = Marker()
    marker.header.frame_id = "/map"
    marker.type = marker.SPHERE
    marker.action = marker.ADD
    marker.scale.x = 0.08
    marker.scale.y = 0.08
    marker.scale.z = 0.08
    marker.color.a = 1.0
    marker.color.r = 0
    marker.color.g = 1
    marker.color.b = 0
    marker.pose.orientation.w = 1.0
    marker.pose.position.x = ee_sg[1][0]
    marker.pose.position.y = ee_sg[1][1] 
    marker.pose.position.z = ee_sg[1][2]
    markerArray.markers.append(marker)
    
    id = 0
    for m in markerArray.markers:
           m.id = id
           id += 1
    publisher.publish(markerArray)

# %%
rospy.init_node('output_node_pos')

# %%
print(stick)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-05e6b75f9ad9> in <module>()
# ----> 1 print(stick)
#
# NameError: name 'stick' is not defined

# %%
stick_file = os.path.join(objects_path,'objects/stick1.kinbody.xml')
stick = env.ReadKinBodyXMLFile(stick_file)
env.AddKinBody(stick)

# %%
topic = 'output_node_pos'
publisher = rospy.Publisher(topic, MarkerArray, queue_size=100)

# %%
from random import randint
def get_output_samples(cond, num_viz):
    c_sample_seed = cond
    c_sample = np.repeat([c_sample_seed],num_viz,axis=0)
    y_viz, z_viz = sess.run([y, z], feed_dict={z: np.random.randn(num_viz, z_dim), c: c_sample})
    
    return y_viz
print("start")
t = randint(0,numTest-1)
t = 199
print("t = ",t)
cond = c_test[t,:]
cond[7] = cond[15] = 0.5
print("cond.shape = ", cond.shape)
num_viz = 300
env, robot = load_herb_and_env(cond)
print("table_box added")
output_samples = np.array(get_output_samples(cond, num_viz))
print(output_samples[0,:])

robot.SetActiveDOFValues([0,0,1,1,1,1,1])
robot.SetActiveDOFValues(output_samples[0,:])

print(type(output_samples))

eepositions = get_eepositions_from_samples(env, robot, output_samples[:,:])
s_conf = cond[:8]
g_conf = cond[8:16]
ee_sg = get_eepositions_from_samples(env, robot, np.array([s_conf, g_conf]))

print("going to publish")
while not rospy.is_shutdown():
        publish_samples(eepositions, ee_sg, publisher)
#         print("published")
        rospy.sleep(0.1)
# Out:
# start
# ('t = ', 199)
# ('cond.shape = ', (48,))
# table_box added
# [ 4.4871974 -1.3746911  2.420879  -2.580197  -4.065078  -1.7611405
#  -1.2509989  0.5730831]
# <type 'numpy.ndarray'>
# going to publish
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-51-529b82755ed2> in <module>()
#      33         publish_samples(eepositions, ee_sg, publisher)
#      34 #         print("published")
# ---> 35         rospy.sleep(0.1)
#
# /opt/ros/indigo/lib/python2.7/dist-packages/rospy/timer.pyc in sleep(duration)
#     123             return
#     124         else:
# --> 125             rospy.rostime.wallsleep(duration)
#     126     else:
#     127         initial_rostime = rospy.rostime.get_rostime()
#
# /opt/ros/indigo/lib/python2.7/dist-packages/rospy/rostime.pyc in wallsleep(duration)
#     294             pass
#     295     else:
# --> 296         time.sleep(duration)
#
# KeyboardInterrupt:

# %%
from random import randint
conditions = [c_test[randint(0, numTest-1), :] for i in range(100)]
step_size = 0.1
stick_len = 0.4

conditions = np.loadtxt("Results/conditions.txt", delimiter = " ")
print("conditions = ", conditions)
# Out:
# ('conditions = ', array([[ 4.91592278, -1.0369205 , -1.20838014, ...,  0.        ,
#          0.        ,  1.        ],
#        [ 1.86172356, -0.37543597, -1.21644414, ...,  0.        ,
#          0.        ,  1.        ],
#        [ 4.18203606, -0.35165911, -2.97324414, ...,  0.        ,
#          0.        ,  1.        ],
#        ...,
#        [ 4.79067864, -0.99790206,  0.91168386, ...,  0.        ,
#          0.        ,  1.        ],
#        [ 5.438872  , -1.00277936, -1.89036414, ...,  0.        ,
#          0.        ,  1.        ],
#        [ 2.3453051 ,  1.2844736 , -0.72676734, ...,  0.        ,
#          0.        ,  1.        ]]))

# %%
def state_to_numpy(state):
#     print("state = ", state)
    strlist = state.split()
#     print("strlist = ", strlist)
    val_list = [float(s) for s in strlist]
    return np.array(val_list)

def edge_to_configs(state1, state2):
    EDGE_DISCRETIZATION = 7
    config1 = state_to_numpy(state1)
    config2 = state_to_numpy(state2)

    diff = config2 - config1
    step = diff/EDGE_DISCRETIZATION

    to_check = list()
    to_check.append(config1)

    for i in xrange(EDGE_DISCRETIZATION - 1):
        conf = config1 + step*(i+1)
        to_check.append(conf)

    return to_check

#get output node posns
def get_o_node_posns(c_sample_seed, num_viz, count, env, robot):
    return []
    print("in get_o_node_posns")
    init = c_sample_seed[:2]
    goal = c_sample_seed[2:4]
    c_sample = np.repeat([c_sample_seed],num_viz,axis=0)
    y_viz, z_viz = sess.run([y, z], feed_dict={z: np.random.randn(num_viz, z_dim), c: c_sample})
    
    free_nodes = []
    y_viz = np.array(y_viz)
    print("output y_viz.shape = ",y_viz.shape)
    y_viz = list(y_viz)
    c_ = 0
    for cc in y_viz:
        robot.SetActiveDOFValues(cc[:-1])
        ee_trans = robot.right_arm.GetEndEffectorTransform()

        push_dir = ee_trans[:3,2]
        parr_dir = ee_trans[:3,1]
        stick_pose = ee_trans
        stick_pose[:3,3] += push_dir*step_size
        stick_pose[:3,3] += parr_dir*stick_len*cc[-1]
        stick.SetTransform(stick_pose)
#         print("added stick")
        if env.CheckCollision(robot) or env.CheckCollision(stick) or robot.CheckSelfCollision():
#             print("in collision count = ", c_)
#             raw_input("Press Enter")
            c_ += 1
            continue
        else:
            free_nodes.append(cc)
        c_ += 1
    y_viz = np.array(free_nodes)
    print("no of nodes in collision = ", num_viz-y_viz.shape[0])
    print("returning o_node_posns of shape = ", y_viz.shape)
    return y_viz

#load shallow_graph
def load_halton_samples(num_viz, env, robot, stick):
    print("loading halton with "+str(num_viz)+"samples")
    shallow_G = nx.read_graphml("graphs/halton8D"+str(num_viz)+"_0.graphml")
    shallow_G.remove_edges_from(list(shallow_G.edges()))
    
    count = 0
    for node in list(shallow_G.nodes()):
        cc = state_to_numpy(shallow_G.node[node]['state'])
        robot.SetActiveDOFValues(cc[:-1])
        ee_trans = robot.right_arm.GetEndEffectorTransform()

        push_dir = ee_trans[:3,2]
        parr_dir = ee_trans[:3,1]
        stick_pose = ee_trans
        stick_pose[:3,3] += push_dir*step_size
        stick_pose[:3,3] += parr_dir*stick_len*cc[-1]
        stick.SetTransform(stick_pose)
        if env.CheckCollision(robot) or env.CheckCollision(stick) or robot.CheckSelfCollision():
             shallow_G.remove_node(node)
#              print("in collision count = ", count)
#              raw_input("Press Enter")
             count += 1
    print("after removing invalid nodes n = ", len(list(shallow_G.nodes())))
    print("count = ", count)
    return shallow_G

def remove_invalid_edges(G, env, robot, stick):
    print("gotta remove invalid edges")
    print("total no of edges = ", len(list(G.edges())))
    to_remove = []
    for edge in G.edges():
        u, v = edge
        state1 = G.node[u]['state']
        state2 = G.node[v]['state']
        configs_to_check = edge_to_configs(state1,state2)

        edge_free = 1
        for cc in configs_to_check:
            robot.SetActiveDOFValues(cc[:-1])
            ee_trans = robot.right_arm.GetEndEffectorTransform()
    
            push_dir = ee_trans[:3,2]
            parr_dir = ee_trans[:3,1]
            stick_pose = ee_trans
            stick_pose[:3,3] += push_dir*step_size
            stick_pose[:3,3] += parr_dir*stick_len*cc[-1]
            stick.SetTransform(stick_pose)
            if env.CheckCollision(robot) or env.CheckCollision(stick) or robot.CheckSelfCollision():
                edge_free = 0
        if(not edge_free):
            to_remove.append((u, v))

    for r in to_remove:
        G.remove_edge(r[0], r[1])

    print("no of edges in collision = ", len(to_remove))    
    print("removed inavlid edges")
    return G

# %%
import time
THRESHOLD = 0.6
def calc_weight(s, g):
    return sqrt(np.sum((s-g)**2))

def connect_within_thresh(G, lmbda, env, robot, stick):
    for node in G.nodes():
        state = G.node[node]['state']
        conf = state_to_numpy(state)
        G1 = G.copy()
        
        for node1 in G1.nodes():
            if(node == node1):
                continue
            state1 = G1.node[node1]['state']
            conf1  = state_to_numpy(state1)
            w = calc_weight(conf, conf1)
            if(w < lmbda*THRESHOLD):
                G.add_edge(node, node1)
                G[node][node1]['weight'] = w
    return G

def connect_knn(G, K, env, robot, stick):
    print("no of nodes = ", len(list(G.nodes())))
    print("gotta connect knn")
    for node in G.nodes():
        state = G.node[node]['state']
        conf = state_to_numpy(state)
        G1 = G.copy()

        for k in range(K):
            w = 1000000
            sn = None
            for node1 in G1.nodes():
            	if(node == node1):
            		continue
                state1 = G1.node[node1]['state']
#                 print("node1 = ",node1)
#                 print("state1 = ",state1)
                
                conf1  = state_to_numpy(state1)
                if(calc_weight(conf, conf1) < w):
                    w = calc_weight(conf, conf1)
                    sn = node1

            # if(check_for_collision(node, sn)==1):
            G.add_edge(node, sn)
            # print("connected edge from ",node, " to ",sn)
            G[node][sn]['weight'] = w
            G1.remove_node(sn)
    print("connected knn")
    return G

def get_path_length(shallow_G, o_node_posns, src_conf, goal_conf, k, env, robot, stick):
    G = shallow_G.copy()
    s_state = " ".join(str(src_conf[i]) for i in range(len(src_conf)))
    g_state = " ".join(str(goal_conf[i]) for i in range(len(goal_conf)))
    
    G.add_node('s', state = s_state)
    G.add_node('g', state = g_state)
    for i in range(len(o_node_posns)):
        curr_state = " ".join(str(o_node_posns[i,j]) for j in range(len(o_node_posns[i])))
#         print("adding curr_state i = ", i, " state = ", curr_state)
        G.add_node('o'+str(i), state = curr_state)
        
#     for node in list(G.nodes()):
#         print("node = ", node," state = ", G.node[node]['state'])
#     print("connecting knn")    
    G = connect_knn(G, k, env, robot, stick)
    
#     G = connect_within_thresh(G, lmbda, env, robot, stick)  
    print("connected knn")
    print("no of edges = ", len(G.edges()))
    print("removing invalid edges")
    t1 = time.time()
    G = remove_invalid_edges(G, env, robot, stick)
    t2 = time.time()
    print("removed invalid edges in time t = ", t2-t1," secs")
    path_length = None
    path_node_posns = []
    try:
        path_length = nx.dijkstra_path_length(G,'s','g', weight = 'weight')
        path_nodes = nx.dijkstra_path(G, 's', 'g', weight = 'weight')
        for node in path_nodes:
            path_node_posns.append(state_to_numpy(G.node[node]['state']))
    except Exception as e:
        pass
    return path_length, path_node_posns

# %%
from random import randint
from math import sqrt
# cond_test = []
# test_cases = []
# for x in range(10):
#     test_cases.append(randint(0,numTest-1))

# test_cases = [1379]

num_v = [1000]

for num_viz in num_v:
    shallow_G = load_halton_samples(num_viz, env, robot, stick)
    path_lengths = []
    all_path_nodes_posns = []
#     lmbda_ = [2]
    k_ = [5]
#     for lmbda in lmbda_:
    for k in k_:
        count = 0
        # print(test_cases)
        # print(conditions[0])
        # return
        failed_c = 0
        for cond in conditions:
            print("---------------------------------------cond = ",cond)
        #     if(count<7):
        #         count+=1
        #         continue
            print("cond.shape = ", cond.shape)
            table_pose = cond[16:32].reshape(4,4)
            box_pose = cond[32:].reshape(4,4)
            table.SetTransform(table_pose)
            tall_white_box.SetTransform(box_pose)
        #     print(cond)
            print("count = ", count)
            o_node_posns = get_o_node_posns(cond, num_viz, count, env, robot)
            print("o_node_posns = ", len(o_node_posns))
            print("got o_node posns")
            path_length, path_node_posns = get_path_length(shallow_G, o_node_posns, cond[:8], cond[8:16], k, env, robot, stick)
            
            if(path_length==None):
                path_lengths.append(-1)
                failed_c += 1
            else:
                path_lengths.append(path_length)
            print("path_length = ", path_length)
            all_path_nodes_posns.append(path_node_posns)
            count += 1
    print("num_viz = ",num_viz, " path_length = ",path_lengths)
    print(failed_c)
    np.savetxt("Results/RF_num_viz+"+str(num_viz)+"_k"+str(k)+".txt", path_lengths, delimiter = " ")
# Out:
# loading halton with 1000samples
# ('after removing invalid nodes n = ', 285)
# ('count = ', 715)
# ('---------------------------------------cond = ', array([ 4.91592278e+00, -1.03692050e+00, -1.20838014e+00, -2.99536262e-01,
#        -2.23559167e+00, -6.33153657e-01, -2.48512710e+00, -2.53212382e-01,
#         1.78701653e+00, -7.46111173e-01, -1.13350014e+00, -9.09282202e-01,
#         1.68777422e+00, -1.96041811e+00,  2.18493193e+00, -1.28558642e-01,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03,  1.31954873e-01,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03, -2.55746912e-01,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  1.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00]))
# ('cond.shape = ', (48,))
# ('count = ', 0)
# ('o_node_posns = ', 0)
# got o_node posns
# ('no of nodes = ', 287)
# gotta connect knn
# connected knn
# connected knn
# ('no of edges = ', 947)
# removing invalid edges
# gotta remove invalid edges
# ('total no of edges = ', 947)
# ('no of edges in collision = ', 296)
# removed inavlid edges
# ('removed invalid edges in time t = ', 22.564171075820923, ' secs')
# ('path_length = ', None)
# ('---------------------------------------cond = ', array([ 1.86172356e+00, -3.75435971e-01, -1.21644414e+00,  2.33098949e-01,
#         4.82460376e-01, -1.89051560e-01,  1.01253218e+00, -4.25978091e-01,
#         3.97439446e+00, -5.30087192e-01,  1.01536386e+00, -3.88708907e+00,
#         5.95772308e-01,  1.62306986e+00,  2.77411667e-01,  3.39009900e-01,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03, -2.40759102e-01,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03, -2.11154595e-01,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  1.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00]))
# ('cond.shape = ', (48,))
# ('count = ', 1)
# ('o_node_posns = ', 0)
# got o_node posns
# ('no of nodes = ', 287)
# gotta connect knn
# connected knn
# connected knn
# ('no of edges = ', 942)
# removing invalid edges
# gotta remove invalid edges
# ('total no of edges = ', 942)
# ('no of edges in collision = ', 370)
# removed inavlid edges
# ('removed invalid edges in time t = ', 21.296823978424072, ' secs')
# ('path_length = ', 16.32852859936482)
# ('---------------------------------------cond = ', array([ 4.18203606e+00, -3.51659107e-01, -2.97324414e+00,  3.19474254e-03,
#         1.47692797e+00,  1.99028390e+00,  1.59506830e+00,  4.96605376e-01,
#         2.15945305e+00, -4.55098624e-01, -9.20921386e-02, -4.18058307e-01,
#        -3.25826772e+00, -1.81252413e+00,  2.81768298e+00, -4.49734815e-01,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03, -2.40759102e-01,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03, -2.11154595e-01,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  1.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00]))
# ('cond.shape = ', (48,))
# ('count = ', 2)
# ('o_node_posns = ', 0)
# got o_node posns
# ('no of nodes = ', 287)
# gotta connect knn
# connected knn
# connected knn
# ('no of edges = ', 945)
# removing invalid edges
# gotta remove invalid edges
# ('total no of edges = ', 945)
# ('no of edges in collision = ', 365)
# removed inavlid edges
# ('removed invalid edges in time t = ', 21.714323043823242, ' secs')
# ('path_length = ', 12.820046576741328)
# ('---------------------------------------cond = ', array([ 2.73586907e+00,  1.00219955e+00,  5.89891861e-01, -1.59709085e+00,
#        -4.15663531e+00, -9.94765645e-01,  2.31330683e+00, -1.24315274e-01,
#         1.51049092e-02,  5.13723880e-01,  9.48624661e-01, -1.46755299e+00,
#        -2.13227657e+00, -1.93885024e+00, -1.15971193e+00, -2.85110541e-01,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03,
' secs')
# ('path_length = ', None)
# ('---------------------------------------cond = ', array([ 1.77493157e+00, -7.15221572e-01,  2.21229186e+00, -3.60939249e-01,
#        -1.73214245e+00,  2.81520199e-01,  1.44011326e+00, -4.59495329e-01,
#         4.33529534e+00, -7.08244316e-01,  1.03056661e-01,  4.34035634e-01,
#        -2.85469990e+00, -1.67345337e+00,  2.15713054e+00,  5.86636782e-02,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03, -4.82408082e-01,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03, -2.04576011e-01,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  1.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00]))
# ('cond.shape = ', (48,))
# ('count = ', 10)
# ('o_node_posns = ', 0)
# got o_node posns
# ('no of nodes = ', 287)
# gotta connect knn
# connected knn
# connected knn
# ('no of edges = ', 944)
# removing invalid edges
# gotta remove invalid edges
# ('total no of edges = ', 944)
# ('no of edges in collision = ', 383)
# removed inavlid edges
# ('removed invalid edges in time t = ', 20.53144598007202, ' secs')
# ('path_length = ', 6.8922258095050974)
# ('---------------------------------------cond = ', array([ 2.08621087e+00, -1.35252280e+00, -2.97977214e+00, -2.79040316e+00,
#        -6.91776357e-01,  2.75918154e-01,  9.51613365e-01,  2.54012087e-01,
#         4.13754143e+00, -2.74164145e-01,  2.68392066e+00,  5.93968995e-01,
#        -4.48409680e+00,  1.97347776e+00, -1.65316867e+00, -1.75772829e-01,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03,  4.54003936e-02,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03,  2.77163934e-02,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  1.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00]))
# ('cond.shape = ', (48,))
# ('count = ', 11)
# ('o_node_posns = ', 0)
# got o_node posns
# ('no of nodes = ', 287)
# gotta connect knn
# connected knn
# connected knn
# ('no of edges = ', 940)
# removing invalid edges
# gotta remove invalid edges
# ('total no of edges = ', 940)
# ('no of edges in collision = ', 404)
# removed inavlid edges
# ('removed invalid edges in time t = ', 19.383828163146973, ' secs')
# ('path_length = ', 15.794613294480282)
# ('---------------------------------------cond = ', array([ 5.30483880e+00, -1.01253397e+00,  2.44153986e+00, -3.58150211e+00,
#        -2.67162746e+00, -1.31212148e+00, -1.67299601e+00, -1.58737968e-01,
#         2.27810540e+00, -9.23319931e-01, -1.38233214e+00,  1.18127530e+00,
#        -3.07467370e+00,  1.15880041e+00,  1.87976317e+00, -2.63494816e-02,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03, -2.94354611e-01,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03, -1.98099212e-01,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  1.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00]))
# ('cond.shape = ', (48,))
# ('count = ', 12)
# ('o_node_posns = ', 0)
# got o_node posns
# ('no of nodes = ', 287)
# gotta connect knn
# connected knn
# connected knn
# ('no of edges = ', 942)
# removing invalid edges
# gotta remove invalid edges
# ('total no of edges = ', 942)
# ('no of edges in collision = ', 379)
# removed inavlid edges
# ('removed invalid edges in time t = ', 20.655640840530396, ' secs')
# ('path_length = ', 13.606732958348712)
# ('---------------------------------------cond = ', array([ 2.05398430e+00, -7.81878078e-01, -2.62649214e+00, -1.82249040e-02,
#        -1.11251265e+00,  1.83440700e+00,  1.96769315e+00,  4.17301196e-01,
#         3.95352044e+00, -9.33277763e-01,  2.00147586e+00, -2.53574736e+00,
#        -4.92352282e+00, -2.05437540e-01,  1.11878090e+00,  4.60740090e-01,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03, -4.82408082e-01,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03, -2.04576011e-01,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  1.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00]))
# ('cond.shape = ', (48,))
# ('count = ', 13)
# ('o_node_posns = ', 0)
# got o_node posns
# ('no of nodes = ', 287)
# gotta connect knn
# connected knn
# connected knn
# ('no of edges = ', 945)
# removing invalid edges
# gotta remove invalid edges
# ('total no of edges = ', 945)
# ('no of edges in collision = ', 379)
# removed inavlid edges
# ('removed invalid edges in time t = ', 21.746840000152588, ' secs')
# ('path_length = ', 15.896604891031705)
# ('---------------------------------------cond = ', array([ 2.27480950e+00, -1.01924027e+00, -2.04588414e+00, -3.52866698e+00,
#        -1.91573647e+00,  1.60248235e+00,  1.21770213e+00, -5.50785429e-02,
#         3.80520501e+00, -8.71498563e-01,  1.87245186e+00, -3.45298423e+00,
#         9.28536463e-01, -1.15330351e+00,  2.66014176e+00, -1.22136039e-01,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03,  4.47693916e-01,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03, -1.13627590e-01,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  1.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00]))
# ('cond.shape = ', (48,))
# ('count = ', 14)
# ('o_node_posns = ', 0)
# got o_node posns
# ('no of nodes = ', 287)
# gotta connect knn
# connected knn
# connected knn
# ('no of edges = ', 940)
# removing invalid edges
# gotta remove invalid edges
# ('total no of edges = ', 940)
# ('no of edges in collision = ', 324)
# removed inavlid edges
# ('removed invalid edges in time t = ', 21.382174015045166, ' secs')
# ('path_length = ', 7.376179300936514)
# ('---------------------------------------cond = ', array([ 2.13619866e+00, -1.40671508e+00,  4.37904661e-01,  1.44456696e+00,
#        -4.28855005e+00,  6.75220898e-02, -1.66042433e+00,  1.30248457e-01,
#         4.47416921e-01,  3.42747233e-01, -2.01286014e+00, -1.43572952e+00,
#        -5.83723628e-01, -1.85650018e+00, -9.24369921e-01, -2.05829381e-01,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03,  4.54003936e-02,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03,  2.77163934e-02,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  1.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00]))
# ('cond.shape = ', (48,))
# ('count = ', 15)
# ('o_node_posns = ', 0)
# got o_node posns
# ('no of nodes = ', 287)
# gotta connect knn
# connected knn
# connected knn
# ('no of edges = ', 940)
# removing invalid edges
# gotta remove invalid edges
# ('total no of edges = ', 940)
# ('no of edges in collision = ', 404)
# removed inavlid edges
# ('removed invalid edges in time t = ', 20.130536794662476, ' secs')
# ('path_length = ', None)
# ('---------------------------------------cond = ', array([
-01,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03, -2.40759102e-01,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03, -2.11154595e-01,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  1.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00]))
# ('cond.shape = ', (48,))
# ('count = ', 22)
# ('o_node_posns = ', 0)
# got o_node posns
# ('no of nodes = ', 287)
# gotta connect knn
# connected knn
# connected knn
# ('no of edges = ', 944)
# removing invalid edges
# gotta remove invalid edges
# ('total no of edges = ', 944)
# ('no of edges in collision = ', 367)
# removed inavlid edges
# ('removed invalid edges in time t = ', 21.38108205795288, ' secs')
# ('path_length = ', 13.165179876612315)
# ('---------------------------------------cond = ', array([ 5.73367180e+00, -1.01233075e+00,  2.85510786e+00, -1.27770012e+00,
#        -8.07988790e-03,  1.69239517e+00, -2.14303349e+00,  1.65223634e-01,
#         3.48971428e+00, -1.45243981e+00, -4.18415339e-01,  1.55452115e+00,
#        -4.71454554e+00,  1.82223956e-01, -1.49555561e+00, -3.90181996e-02,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03,  1.31954873e-01,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03, -2.55746912e-01,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  1.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00]))
# ('cond.shape = ', (48,))
# ('count = ', 23)
# ('o_node_posns = ', 0)
# got o_node posns
# ('no of nodes = ', 287)
# gotta connect knn
# connected knn
# connected knn
# ('no of edges = ', 941)
# removing invalid edges
# gotta remove invalid edges
# ('total no of edges = ', 941)
# ('no of edges in collision = ', 294)
# removed inavlid edges
# ('removed invalid edges in time t = ', 22.14971399307251, ' secs')
# ('path_length = ', None)
# ('---------------------------------------cond = ', array([ 4.29629387e+00, -8.93039994e-01, -2.88108414e+00, -3.99847123e+00,
#         8.45345425e-01,  7.23101376e-01, -1.98075095e+00,  3.74138544e-01,
#         2.81094231e+00, -4.13844750e-01,  1.74803586e+00,  1.98237009e+00,
#        -3.91949304e+00, -4.02069311e-01,  1.57308581e+00,  3.99506674e-01,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03, -1.24025955e-01,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03, -2.64997891e-01,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  1.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00]))
# ('cond.shape = ', (48,))
# ('count = ', 24)
# ('o_node_posns = ', 0)
# got o_node posns
# ('no of nodes = ', 287)
# gotta connect knn
# connected knn
# connected knn
# ('no of edges = ', 941)
# removing invalid edges
# gotta remove invalid edges
# ('total no of edges = ', 941)
# ('no of edges in collision = ', 353)
# removed inavlid edges
# ('removed invalid edges in time t = ', 21.46010684967041, ' secs')
# ('path_length = ', None)
# ('---------------------------------------cond = ', array([ 1.79800286e+00, -1.05825871e+00, -2.23942014e+00,  1.87403703e-01,
#        -2.14522899e+00, -8.47852022e-01, -6.49516890e-01,  1.54864598e-01,
#         1.06320061e+00,  1.03925352e+00,  8.88486614e-02, -2.27007575e+00,
#         3.03212808e-01, -5.76842334e-01,  9.43280131e-01,  1.89156845e-01,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03,  4.54003936e-02,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03,  2.77163934e-02,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  1.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00]))
# ('cond.shape = ', (48,))
# ('count = ', 25)
# ('o_node_posns = ', 0)
# got o_node posns
# ('no of nodes = ', 287)
# gotta connect knn
# connected knn
# connected knn
# ('no of edges = ', 943)
# removing invalid edges
# gotta remove invalid edges
# ('total no of edges = ', 943)
# ('no of edges in collision = ', 402)
# removed inavlid edges
# ('removed invalid edges in time t = ', 20.455429792404175, ' secs')
# ('path_length = ', None)
# ('---------------------------------------cond = ', array([ 3.94253411e+00,  3.73059895e-02,  2.63737986e+00,  2.37649158e+00,
#        -4.46453778e+00,  1.23316755e+00,  1.60171692e-01, -4.51783602e-01,
#         2.08621087e+00, -1.35252280e+00, -2.97977214e+00, -2.79040316e+00,
#        -6.91776357e-01,  2.75918154e-01,  9.51613365e-01,  2.54012087e-01,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03,  4.54003936e-02,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03,  2.77163934e-02,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  1.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00]))
# ('cond.shape = ', (48,))
# ('count = ', 26)
# ('o_node_posns = ', 0)
# got o_node posns
# ('no of nodes = ', 287)
# gotta connect knn
# connected knn
# connected knn
# ('no of edges = ', 942)
# removing invalid edges
# gotta remove invalid edges
# ('total no of edges = ', 942)
# ('no of edges in collision = ', 406)
# removed inavlid edges
# ('removed invalid edges in time t = ', 20.200813055038452, ' secs')
# ('path_length = ', 18.531086526017276)
# ('---------------------------------------cond = ', array([ 1.75186028e+00, -4.60788813e-01,  1.24921986e+00, -2.29565417e-01,
#         3.73451428e-01,  5.52098960e-01,  1.23235713e+00,  4.53304603e-01,
#         5.13656487e+00, -1.20329080e+00,  7.40880661e-01,  1.94007478e+00,
#         8.53516749e-01, -1.22600486e-04, -1.01323380e+00, -3.61805778e-01,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03, -2.40759102e-01,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03, -2.11154595e-01,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  1.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00]))
# ('cond.shape = ', (48,))
# ('count = ', 27)
# ('o_node_posns = ', 0)
# got o_node posns
# ('no of nodes = ', 287)
# gotta connect knn
# connected knn
# connected knn
# ('no of edges = ', 944)
# removing invalid edges
# gotta remove invalid edges
# ('total no of edges = ', 944)
# ('no of edges in collision = ', 368)
# removed inavlid edges
# ('removed invalid edges in time t = ', 21.36667799949646, ' secs')
# ('path_length = ', 7.57998818337383)
# ('---------------------------------------cond = ', array([ 2.39529290e+00,  9.20301468e-01,  5.47267861e-01,  2.74986258e-01,
#        -1.85453846e+00, -1.66643381e-01, -4.45496344e-01, -1.14992141e-01,
#         3.21337178e-02,  7.64634141e-01, -1.70412414e+00, -2.99507979e+00,
#         1.10878371e+00, -9.80900584e-01,  1.64025455e+00, -5.71196568e-02,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03, -4.82408082e-01,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03, -2.04576011e-01,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  1.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00]))
# ('cond.shape = ', (48,))
# ('count = ', 28)
# ('o_node_posns = ', 0)
# got o_node posns
# ('no of nodes = ', 287)
# gotta connect knn
# connected knn
# connected knn
# ('no of edges = ', 944)
# removing invalid edges
# gotta remove invalid edges
# ('total no of edges = ', 944)
# ('no of edges in collision = ', 375)
# removed inavlid edges
# ('removed invalid edges in time t = ', 21.280583143234253, ' secs')
# ('path_length = ', 11.601647492017948)
# ('---------------------------------------cond = ', array([ 2.39730706e+00, -4.19873641e-01,  2.13672066e+00,  1.04092562e+00,
#         3.28074498e-01, -1.14700121e+00,  1.19356449e+00,  3.97780168e-01,
#         4.45614495e+00, -6.13407824e-01, -2.24702334e+00,  7.98974769e-02,
#        -1.22530300e+00,  1.49618355e+00, -4.89389497e-01, -8.90331626e-02,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03, -1.24025955e-01,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03, -2.64997891e-01,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  1.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00]))
# ('cond.shape = ', (48,))
# ('count = ', 29)
# ('o_node_posns = ', 0)
# got o_node posns
# ('no of nodes = ', 287)
# gotta connect knn
# connected knn
# connected knn
# ('no of edges = ', 943)
# removing invalid edges
# gotta remove invalid edges
# ('total no of edges = ', 943)
# ('no of edges in collision = ', 354)
# removed inavlid edges
# ('removed invalid edges in time t = ', 21.591493129730225, ' secs')
# ('path_length = ', 18.453787106135263)
# ('---------------------------------------cond = ', array([ 2.08621087e+00, -1.35252280e+00, -2.97977214e+00, -2.79040316e+00,
#        -6.91776357e-01,  2.75918154e-01,  9.51613365e-01,  2.54012087e-01,
#         4.13754143e+00, -2.74164145e-01,  2.68392066e+00,  5.93968995e-01,
#        -4.48409680e+00,  1.97347776e+00, -1.65316867e+00, -1.75772829e-01,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03,  4.54003936e-02,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03,  2.77163934e-02,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  1.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00]))
# ('cond.shape = ', (48,))
# ('count = ', 30)
# ('o_node_posns = ', 0)
# got o_node posns
# ('no of nodes = ', 287)
# gotta connect knn
# connected knn
# connected knn
# ('no of edges = ', 940)
# removing invalid edges
# gotta remove invalid edges
# ('total no of edges = ', 940)
# ('no of edges in collision = ', 404)
# removed inavlid edges
# ('removed invalid edges in time t = ', 20.308658123016357, ' secs')
# ('path_length = ', 15.794613294480282)
# ('---------------------------------------cond = ', array([ 1.68978753e+00, -9.44183960e-01, -1.89566334e+00,  5.66837442e-01,
#        -3.85442670e+00, -1.55875150e+00,  2.32199926e+00, -1.63088764e-01,
#         1.75863518e+00,  9.16508008e-01, -1.66679934e+00,  1.19705104e+00,
#        -9.18834866e-01, -1.22542984e+00,  2.41481424e+00,  7.89290230e-02,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03,  4.54003936e-02,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03,  2.77163934e-02,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  1.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00]))
# ('cond.shape = ', (48,))
# ('count = ', 31)
# ('o_node_posns = ', 0)
# got o_node posns
# ('no of nodes = ', 287)
# gotta connect knn
# connected knn
# connected knn
# ('no of edges = ', 945)
# removing invalid edges
# gotta remove invalid edges
# ('total no of edges = ', 945)
# ('no of edges in collision = ', 406)
# removed inavlid edges
# ('removed invalid edges in time t = ', 20.28327512741089, ' secs')
# ('path_length = ', None)
# ('---------------------------------------cond = ', array([ 4.41659417e+00, -8.91414226e-01, -1.91524734e+00, -3.99902606e-01,
#        -2.55635963e+00, -3.31746645e-02, -7.23869448e-01,  1.90162055e-01,
#         2.10891594e+00, -6.12798161e-01, -1.66802814e+00, -3.56293842e+00,
#        -1.98458423e+00,  1.76718247e+00,  1.14701332e+00, -2.18797360e-01,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03, -1.24025955e-01,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03, -2.64997891e-01,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  1.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00]))
# ('cond.shape = ', (48,))
# ('count = ', 32)
# ('o_node_posns = ', 0)
# got o_node posns
# ('no of nodes = ', 287)
# gotta connect knn
# connected knn
# connected knn
# ('no of edges = ', 945)
# removing invalid edges
# gotta remove invalid edges
# ('total no of edges = ', 945)
# ('no of edges in collision = ', 353)
# removed inavlid edges
# ('removed invalid edges in time t = ', 21.679205179214478, ' secs')
# ('path_length = ', 15.334509551330665)
# ('---------------------------------------cond = ', array([ 2.44418206e+00,  1.16037327e+00, -7.91279339e-01, -3.22729595e+00,
#         7.90884415e-01,  9.35839026e-01,  2.20964428e+00, -2.91970525e-01,
#         1.43783440e+00,  6.06799122e-01,  9.55536661e-01, -3.54145077e+00,
#         5.21230703e-01,  1.13583202e+00, -1.64461992e+00,  4.68344390e-01,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03,  4.47693916e-01,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03, -1.13627590e-01,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  1.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00]))
# ('cond.shape = ', (48,))
# ('count = ', 33)
# ('o_node_posns = ', 0)
# got o_node posns
# ('no of nodes = ', 287)
# gotta connect knn
# connected knn
# connected knn
# ('no of edges = ', 940)
# removing invalid edges
# gotta remove invalid edges
# ('total no of edges = ', 940)
# ('no of edges in collision = ', 328)
# removed inavlid edges
# ('removed invalid edges in time t = ', 21.38019299507141, ' secs')
# ('path_length = ', 5.567780508334296)
# ('---------------------------------------cond = ', array([ 1.35635247e+00, -3.87629234e-01,  1.16627586e+00, -1.08635128e+00,
#        -3.92953334e+00, -1.19573900e+00,  2.19958693e+00, -2.84266471e-01,
#         4.06832757e+00, -5.71679768e-01,  2.12174466e+00, -1.34807896e+00,
#         1.82742564e+00,  9.01246399e-01,  2.54678105e+00, -3.85715969e-01,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03, -4.82408082e-01,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03, -2.04576011e-01,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  1.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00]))
# ('cond.shape = ', (48,))
# ('count = ', 34)
# ('o_node_posns = ', 0)
# got o_node posns
# ('no of nodes = ', 287)
# gotta connect knn
# connected knn
# connected knn
# ('no of edges = ', 940)
# removing invalid edges
# gotta remove invalid edges
# ('total no of edges = ', 940)
# ('no of edges in collision = ', 375)
# removed inavlid edges
# ('removed invalid edges in time t = ', 21.452815055847168, ' secs')
# ('path_length = ', 9.887235044343294)
# ...
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03, -1.60682005e-02,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  1.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00]))
# ('cond.shape = ', (48,))
# ('count = ', 89)
# ('o_node_posns = ', 0)
# got o_node posns
# ('no of nodes = ', 287)
# gotta connect knn
# connected knn
# connected knn
# ('no of edges = ', 941)
# removing invalid edges
# gotta remove invalid edges
# ('total no of edges = ', 941)
# ('no of edges in collision = ', 354)
# removed inavlid edges
# ('removed invalid edges in time t = ', 20.865113019943237, ' secs')
# ('path_length = ', None)
# ('---------------------------------------cond = ', array([ 1.54641594e+00, -8.10329025e-01,  2.60397186e+00, -1.44048944e+00,
#        -2.04769467e+00, -1.92512523e+00,  2.89095796e+00,  1.46853609e-01,
#         4.26278557e+00, -5.10984413e-01, -1.27012734e+00, -3.19935926e-01,
#        -8.93150246e-02, -1.56253288e+00,  1.70886005e+00,  4.17600457e-01,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03,  9.82925092e-02,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03, -1.09965552e-01,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  1.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00]))
# ('cond.shape = ', (48,))
# ('count = ', 90)
# ('o_node_posns = ', 0)
# got o_node posns
# ('no of nodes = ', 287)
# gotta connect knn
# connected knn
# connected knn
# ('no of edges = ', 945)
# removing invalid edges
# gotta remove invalid edges
# ('total no of edges = ', 945)
# ('no of edges in collision = ', 376)
# removed inavlid edges
# ('removed invalid edges in time t = ', 21.09594488143921, ' secs')
# ('path_length = ', 10.245325293859034)
# ('---------------------------------------cond = ', array([ 2.48043694e+00,  1.27742860e+00,  7.85040661e-01, -1.14483032e+00,
#        -3.75306750e+00, -1.68591792e+00,  1.48551502e+00,  5.44356567e-02,
#         1.29116692e+00,  8.36574394e-01, -1.72486014e+00,  3.83512467e-01,
#        -2.31926082e+00, -5.78393669e-01, -2.29461214e+00,  3.78658153e-01,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03,  1.31954873e-01,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03, -2.55746912e-01,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  1.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00]))
# ('cond.shape = ', (48,))
# ('count = ', 91)
# ('o_node_posns = ', 0)
# got o_node posns
# ('no of nodes = ', 287)
# gotta connect knn
# connected knn
# connected knn
# ('no of edges = ', 943)
# removing invalid edges
# gotta remove invalid edges
# ('total no of edges = ', 943)
# ('no of edges in collision = ', 290)
# removed inavlid edges
# ('removed invalid edges in time t = ', 22.2767391204834, ' secs')
# ('path_length = ', 12.152889348479004)
# ('---------------------------------------cond = ', array([ 2.39730706e+00, -4.19873641e-01,  2.13672066e+00,  1.04092562e+00,
#         3.28074498e-01, -1.14700121e+00,  1.19356449e+00,  3.97780168e-01,
#         4.69399895e+00, -9.67825342e-01, -2.30047614e+00, -3.66718070e+00,
#        -4.49035569e+00, -1.18271425e+00,  2.30712874e+00,  2.66404564e-01,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03,  1.31954873e-01,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03, -2.55746912e-01,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  1.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00]))
# ('cond.shape = ', (48,))
# ('count = ', 92)
# ('o_node_posns = ', 0)
# got o_node posns
# ('no of nodes = ', 287)
# gotta connect knn
# connected knn
# connected knn
# ('no of edges = ', 942)
# removing invalid edges
# gotta remove invalid edges
# ('total no of edges = ', 942)
# ('no of edges in collision = ', 291)
# removed inavlid edges
# ('removed invalid edges in time t = ', 22.31774115562439, ' secs')
# ('path_length = ', 16.205882206287846)
# ('---------------------------------------cond = ', array([ 2.19351067e+00, -1.11678637e+00, -2.37766014e+00, -2.13163003e+00,
#        -3.35006473e+00, -1.28481151e+00,  1.90045258e+00,  3.15092036e-01,
#         4.35232415e+00, -1.01659839e+00,  2.70787861e-01,  2.63067139e+00,
#        -4.85754372e+00,  1.63399385e+00, -1.67040984e+00, -2.50726213e-01,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03,  4.54003936e-02,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03,  2.77163934e-02,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  1.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00]))
# ('cond.shape = ', (48,))
# ('count = ', 93)
# ('o_node_posns = ', 0)
# got o_node posns
# ('no of nodes = ', 287)
# gotta connect knn
# connected knn
# connected knn
# ('no of edges = ', 940)
# removing invalid edges
# gotta remove invalid edges
# ('total no of edges = ', 940)
# ('no of edges in collision = ', 407)
# removed inavlid edges
# ('removed invalid edges in time t = ', 20.585014820098877, ' secs')
# ('path_length = ', 15.013174745766015)
# ('---------------------------------------cond = ', array([ 2.30630364e+00,  1.02760218e+00, -1.52671614e+00, -3.19051940e-01,
#        -2.06108173e+00,  5.56020392e-01,  8.06212807e-01, -4.37641599e-01,
#         2.02175774e+00,  2.13092201e-01,  1.28454786e+00, -3.48677967e+00,
#         1.24408868e+00, -4.52347663e-01, -4.16186350e-01,  2.37683176e-01,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03,  4.54003936e-02,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03,  2.77163934e-02,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  1.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00]))
# ('cond.shape = ', (48,))
# ('count = ', 94)
# ('o_node_posns = ', 0)
# got o_node posns
# ('no of nodes = ', 287)
# gotta connect knn
# connected knn
# connected knn
# ('no of edges = ', 946)
# removing invalid edges
# gotta remove invalid edges
# ('total no of edges = ', 946)
# ('no of edges in collision = ', 411)
# removed inavlid edges
# ('removed invalid edges in time t = ', 20.544624090194702, ' secs')
# ('path_length = ', 16.06222841105243)
# ('---------------------------------------cond = ', array([ 2.68789544e+00, -7.35746899e-01, -2.50092414e+00, -1.69609722e+00,
#        -2.84087819e+00, -1.05750855e+00,  1.86618575e+00,  3.61017098e-01,
#         4.78738274e+00, -6.92257593e-01,  2.10054786e+00,  1.55112120e+00,
#         1.97029053e-01, -9.02051805e-01,  1.59765448e+00,  1.18423809e-01,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03, -1.24025955e-01,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03, -2.64997891e-01,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  1.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00]))
# ('cond.shape = ', (48,))
# ('count = ', 95)
# ('o_node_posns = ', 0)
# got o_node posns
# ('no of nodes = ', 287)
# gotta connect knn
# connected knn
# connected knn
# ('no of edges = ', 948)
# removing invalid edges
# gotta remove invalid edges
# ('total no of edges = ', 948)
# ('no of edges in collision = ', 353)
# removed inavlid edges
# ('removed invalid edges in time t = ', 22.039446115493774, ' secs')
# ('path_length = ', 13.19924385061841)
# ('---------------------------------------cond = ', array([ 5.16787591e+00, -1.32955882e+00,  2.68729986e+00, -3.47487987e+00,
#        -1.56241361e+00, -1.79837896e+00, -1.28219610e+00, -1.12083937e-01,
#         2.27810540e+00, -9.23319931e-01, -1.38233214e+00,  1.18127530e+00,
#        -3.07467370e+00,  1.15880041e+00,  1.87976317e+00, -2.63494816e-02,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03,  1.31954873e-01,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03, -2.55746912e-01,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  1.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00]))
# ('cond.shape = ', (48,))
# ('count = ', 96)
# ('o_node_posns = ', 0)
# got o_node posns
# ('no of nodes = ', 287)
# gotta connect knn
# connected knn
# connected knn
# ('no of edges = ', 942)
# removing invalid edges
# gotta remove invalid edges
# ('total no of edges = ', 942)
# ('no of edges in collision = ', 292)
# removed inavlid edges
# ('removed invalid edges in time t = ', 22.051133155822754, ' secs')
# ('path_length = ', 13.56796826358698)
# ('---------------------------------------cond = ', array([ 4.79067864e+00, -9.97902058e-01,  9.11683861e-01,  1.75674981e+00,
#         1.87280257e+00,  1.00376382e+00,  3.28704157e-01,  1.24685271e-01,
#         1.10970940e+00, -1.83324334e-01,  1.33953666e+00, -9.52529488e-01,
#        -4.10686847e+00,  1.06300544e+00,  2.52716921e+00,  3.57541066e-01,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03, -1.24025955e-01,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03, -2.64997891e-01,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  1.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00]))
# ('cond.shape = ', (48,))
# ('count = ', 97)
# ('o_node_posns = ', 0)
# got o_node posns
# ('no of nodes = ', 287)
# gotta connect knn
# connected knn
# connected knn
# ('no of edges = ', 943)
# removing invalid edges
# gotta remove invalid edges
# ('total no of edges = ', 943)
# ('no of edges in collision = ', 352)
# removed inavlid edges
# ('removed invalid edges in time t = ', 21.862688064575195, ' secs')
# ('path_length = ', 12.478867821843401)
# ('---------------------------------------cond = ', array([ 5.43887200e+00, -1.00277936e+00, -1.89036414e+00,  6.02944847e-01,
#         1.03467675e+00, -1.61463190e+00, -9.02563444e-02,  2.21929767e-01,
#         4.24465813e+00, -6.84941635e-01, -1.76594814e+00,  1.32835688e+00,
#        -4.21496466e+00, -1.88521066e+00,  2.78470923e+00,  2.62905512e-01,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03, -4.62462136e-01,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03, -9.76796143e-02,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  1.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00]))
# ('cond.shape = ', (48,))
# ('count = ', 98)
# ('o_node_posns = ', 0)
# got o_node posns
# ('no of nodes = ', 287)
# gotta connect knn
# connected knn
# connected knn
# ('no of edges = ', 943)
# removing invalid edges
# gotta remove invalid edges
# ('total no of edges = ', 943)
# ('no of edges in collision = ', 433)
# removed inavlid edges
# ('removed invalid edges in time t = ', 20.414374828338623, ' secs')
# ('path_length = ', None)
# ('---------------------------------------cond = ', array([ 2.34530510e+00,  1.28447360e+00, -7.26767339e-01, -7.56420724e-01,
#        -2.65150340e+00,  1.68539261e+00, -1.28686558e+00, -2.36722330e-01,
#         1.09011712e+00,  9.81267784e-01, -1.76572139e-01,  3.14969598e-01,
#         1.05427924e+00, -1.56659436e+00, -1.80841106e+00, -2.77698075e-01,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03, -2.40759102e-01,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#         3.29499984e-03, -5.97027617e-08,  9.99994571e-01,  8.00000000e-01,
#         9.99994571e-01, -5.95063642e-08, -3.29499984e-03, -2.11154595e-01,
#         5.97027617e-08,  1.00000000e+00,  5.95063642e-08,  1.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00]))
# ('cond.shape = ', (48,))
# ('count = ', 99)
# ('o_node_posns = ', 0)
# got o_node posns
# ('no of nodes = ', 287)
# gotta connect knn
# connected knn
# connected knn
# ('no of edges = ', 942)
# removing invalid edges
# gotta remove invalid edges
# ('total no of edges = ', 942)
# ('no of edges in collision = ', 365)
# removed inavlid edges
# ('removed invalid edges in time t = ', 21.63331890106201, ' secs')
# ('path_length = ', None)
